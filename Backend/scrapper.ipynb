# %%
# !pip install requests
# Out:
# Requirement already satisfied: requests in c:\users\fedor\appdata\local\programs\python\python311\lib\site-packages (2.28.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\fedor\appdata\local\programs\python\python311\lib\site-packages (from requests) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\fedor\appdata\local\programs\python\python311\lib\site-packages (from requests) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\fedor\appdata\local\programs\python\python311\lib\site-packages (from requests) (1.26.14)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\fedor\appdata\local\programs\python\python311\lib\site-packages (from requests) (2022.12.7)

# %%
import requests
import time
import json
from collections import Counter
from types import SimpleNamespace
from urllib.parse import urljoin

# %%
class Category:
    id_ = 0
    
    def __init__(self, parent, value, tag, title):
        Category.id_ += 1
        self.id_ = Category.id_
        self.parent = parent
        self.value = value
        self.tag = tag
        self.title = title
        
    def to_dict(self):
        return {'id': self.id_, 
                'parent_id': self.parent.id_ if self.parent else None, 
                'title': self.title}
    

class Offer:
    def __init__(self, title, images, category):
        self.title = title
        self.images = images
        self.category = category
        
    def to_dict(self):
        return {'title': self.title,
                'images': self.images,
                'category_id': self.category.id_}

# %%
headers = {'User-agent': 'targetapp_android_21'}

# %%
included_categories = ['ladies', 'men', 'shop-by-product']
skipped_categories = ['shop-by-product']
excluded_categories = ['view-all', 'hm-plus', 'beauty', 'maternity-wear', 
                       'accessories', 'lingerie', 'premium-selection', 'underwear']

def create_category(parent, category):
    return Category(parent, category.CategoryValue, next(iter(category.tagCodes), None), category.CatName) if category else None
    

def get_processed_categories(categories, raw_parent=None, processed_parent=None, level=0):
    subcategories = None
    if not raw_parent:
        Category.id_ = 0
        subcategories = categories
    elif hasattr(raw_parent, 'CategoriesArray'):
        subcategories = raw_parent.CategoriesArray
    else:
        subcategories = []
        
    processed_subcategories = []
    for subcategory in subcategories:
        if (level <= 1 and subcategory.CategoryValue in included_categories 
            or level > 1 and subcategory.CategoryValue not in excluded_categories):
            if subcategory.CategoryValue not in skipped_categories:
                processed_subcategory = create_category(processed_parent, subcategory)
                processed_subcategories.append(processed_subcategory)
                processed_subcategories.extend(get_processed_categories(None, subcategory, processed_subcategory, level + 1))
            else:
                processed_subcategories.extend(get_processed_categories(None, subcategory, processed_parent, level + 1))
                
    return processed_subcategories

def get_categories():
    response = requests.get('https://app2.hm.com/content/hmonline/en_us/search-results.hm.v1.json', headers=headers)
    return get_processed_categories(json.loads(response.content, object_hook=lambda d: SimpleNamespace(**d))[0].Categories[0])

# %%
def create_offer(offer, category):
    return Offer(offer.name, [x.baseUrl for x in offer.galleryImages[:3]], category)

def get_offers(categories):
    offers = []
    intermediate_categories = set(map(lambda x: x.parent.id_ if x.parent else None, categories))
    processed = set()
    
    for category in [x for x in categories if x.id_ not in intermediate_categories]:
        print(f'Processing category {category.tag}')
        query = f':stock:category:{category.tag}'
        params = {'currentPage': 0, 'pageSize': 10, 'q': query}
        response = requests.get('https://app2.hm.com/hmwebservices/service/products/plp/hm-us/Online/en', 
                                headers=headers,
                                params=params)
        for offer in json.loads(response.content, object_hook=lambda d: SimpleNamespace(**d)).results:
            if offer.pk not in processed:
                offers.append(create_offer(offer, category))
                processed.add(offer.pk)
            
        time.sleep(1)
    return offers

# %%
categories = get_categories()
with open("categories.json", "w", encoding="utf-8") as f:
    json.dump([x.to_dict() for x in categories], f)

# %%
offers = get_offers(categories)
with open("offers.json", "w", encoding="utf-8") as f:
    json.dump([x.to_dict() for x in  offers], f)
# Out:
# Processing category ladies_dresses_cutout
# Processing category ladies_dresses_sleeveless
# Processing category ladies_dresses_puffsleeve
# Processing category ladies_dresses_halterneck
# Processing category ladies_dresses_weddingguest
# Processing category ladies_dresses_camidresses
# Processing category ladies_dresses_knitted
# Processing category ladies_dresses_denim
# Processing category ladies_dresses_shortdresses
# Processing category ladies_dresses_mididresses
# Processing category ladies_dresses_maxidresses
# Processing category ladies_dresses_bodycon
# Processing category ladies_dresses_party
# Processing category ladies_dresses_cocktail
# Processing category ladies_dresses_shirt
# Processing category ladies_dresses_sequin
# Processing category Ladies_dresses_wrap
# Processing category ladies_dresses_sweater
# Processing category ladies_tops_collared
# Processing category ladies_tops_turtleneck
# Processing category ladies_tops_halterneck
# Processing category ladies_tops_cutout
# Processing category ladies_tops_tube
# Processing category ladies_tops_puffsleeve
# Processing category ladies_tops_vests
# Processing category ladies_tops_shortsleeve
# Processing category ladies_tops_longsleeve
# Processing category ladies_tops_bodys
# Processing category ladies_tops_tshirts
# Processing category ladies_tops_printed_tshirts
# Processing category ladies_shirtsblouses_shirts
# Processing category ladies_shirtsblouses_tunics
# Processing category ladies_shirtblouses_offshoulderblouses
# Processing category ladies_shirtsblouses_denimshirts
# Processing category ladies_trousers_highwaisted
# Processing category ladies_trousers_cargo
# Processing category ladies_trousers_leggings
# Processing category ladies_trousers_joggers
# Processing category ladies_trousers_flare
# Processing category ladies_trousers_chinosslacks
# Processing category ladies_trousers_dressed
# Processing category ladies_cardigansjumpers_boleros
# Processing category ladies_cardigansjumpers_sweatervests
# Processing category ladies_cardigansjumpers_cardigans
# Processing category ladies_cardigansjumpers_jumpers
# Processing category ladies_jacketscoats_raincoats
# Processing category ladies_jacketscoats_anoraks
# Processing category ladies_jacketscoats_gilets
# Processing category ladies_jacketscoats_shirtjackets
# Processing category ladies_jacketscoats_trench
# Processing category ladies_jacketscoats_jackets
# Processing category ladies_jacketscoats_coats
# Processing category ladies_jacketscoats_parkas
# Processing category ladies_jacketscoats_coats
# Processing category ladies_jacketscoats_biker
# Processing category ladies_jacketscoats_denim
# Processing category ladies_blazerswaistcoats
# Processing category ladies_jeans_baggy
# Processing category ladies_jeans_boyfriend
# Processing category ladies_jeans_wide
# Processing category ladies_jeans_skinny
# Processing category ladies_jeans_shaping
# Processing category ladies_jeans_curvy
# Processing category ladies_jeans_straight
# Processing category ladies_jeans_bootcut
# Processing category ladies_jeans_flare
# Processing category ladies_jeans_loose
# Processing category ladies_jeans_mom
# Processing category ladies_jumpsuits_dungarees
# Processing category ladies_jumpsuits_long
# Processing category ladies_jumpsuits_short
# Processing category ladies_skirts_pleated
# Processing category ladies_skirts_shortskirts
# Processing category ladies_skirts_midiskirts
# Processing category ladies_skirts_longskirts
# Processing category Ladies_skirts_pencil
# Processing category Ladies_skirts_denim
# Processing category Ladies_skirts_highwaisted
# Processing category Ladies_skirts_a-line
# Processing category Ladies_skirts_wrap
# Processing category ladies_shoes_rainboots
# Processing category ladies_shoes_pumps
# Processing category ladies_shoes_heels
# Processing category ladies_shoes_ballerinas
# Processing category ladies_shoes_espandrilles
# Processing category ladies_shoes_sandals
# Processing category ladies_shoes_flats
# Processing category ladies_shoes_mules
# Processing category ladies_shoes_sneakers
# Processing category ladies_shoes_boots_combat
# Processing category ladies_shoes_ankle_boots
# Processing category Ladies_shoes_loafers
# Processing category Ladies_shoes_slipon
# Processing category Ladies_shoes_flipflops
# Processing category ladies_shoes_slippers
# Processing category ladies_hoodiesswetshirts_hoodies
# Processing category ladies_hoodiesswetshirts_sweatshirts
# Processing category ladies_basics_tops_vests
# Processing category ladies_basics_tops_shortsleeve
# Processing category ladies_basics_tops_longsleeve
# Processing category ladies_basics_cardigansjumpers
# Processing category ladies_basics_dressesskirts
# Processing category ladies_basics_trousersleggings
# Processing category ladies_loungewear
# Processing category ladies_nightwear_nightslips
# Processing category ladies_nightwear_pyjamas
# Processing category ladies_sockstights_socks_sport
# Processing category ladies_sockstights_socks_kneehigh
# Processing category ladies_sockstights_socks_ankle
# Processing category ladies_sockstights_tightleggings
# Processing category ladies_sockstights_shape
# Processing category ladies_sport_sportbras
# Processing category ladies_sport_tops_vest
# Processing category ladies_sport_tops_shortsleeve
# Processing category ladies_sport_tops_longsleeve
# Processing category ladies_sport_jackets
# Processing category ladies_sport_hoodiessweatshirts
# Processing category ladies_sport_trousersjoggers
# Processing category ladies_sport_sportaccessories
# Processing category ladies_sportswear_yoga
# Processing category ladies_swimwear_bikinisets_tops
# Processing category ladies_swimwear_bikinisets_bottoms
# Processing category ladies_swimwear_swimsuits
# Processing category ladies_swimwear_beachwear
# Processing category ladies_shorts_biker
# Processing category ladies_shorts_jeans
# Processing category Ladies_shorts_highwaisted
# Processing category ladies_takecare
# Processing category men_tshirtstanks_tanks
# Processing category men_tshirtstanks_shortsleeve
# Processing category men_tshirtstanks_printed
# Processing category men_tshirtstanks_longsleeve
# Processing category MEN_TSHIRTSTANKS_POLO
# Processing category men_tshirtstanks_bestbasics
# Processing category men_tshirtstanks_multipacks
# Processing category men_trousers_chinos
# Processing category men_trousers_joggers
# Processing category men_trousers_cargo
# Processing category men_trousers_dressed
# Processing category men_trousers_linentrousers
# Processing category men_hoodiessweatshirts_printed
# Processing category men_hoodiessweatshirts_hoodies
# Processing category men_hoodiessweatshirts_sweatshirts
# Processing category men_shirts_longsleeved
# Processing category men_shirts_casual
# Processing category men_shirt_dressed_slimfit
# Processing category men_shirt_dressed_regularfit
# Processing category men_shirts_denim
# Processing category men_shirts_shortsleeved
# Processing category men_shirts_flannel
# Processing category men_shirts_linenshirts
# Processing category men_jacketscoats_shirtjackets
# Processing category men_blazerssuits_waistcoats
# Processing category men_blazerssuits_blazers
# Processing category men_blazerssuits_suits
# Processing category men_blazerssuits_trousers
# Processing category men_jeans_joggers
# Processing category men_jeans_skinny
# Processing category men_jeans_slim
# Processing category men_jeans_regular
# Processing category men_jeans_relaxed
# Processing category men_jeans_straight
# Processing category men_jeans_tapered
# Processing category men_jeans_loose
# Processing category men_shorts_linen
# Processing category men_shorts_joggers
# Processing category men_shorts_denim
# Processing category men_shorts_chinos
# Processing category men_shorts_cargo
# Processing category men_shorts_casual
# Processing category men_swimweear
# Processing category men_sport_tops
# Processing category men_sport_bottoms_shorts
# Processing category men_sport_jackets
# Processing category men_sport_bottoms_trousers
# Processing category men_sport_bottoms_leggingstights
# Processing category men_sport_sportaccessories
# Processing category men_sport_bottoms
# Processing category men_basics_tshirts
# Processing category men_basics_tanktops
# Processing category men_basics_hoodiessweatshirts
# Processing category men_basics_bottoms
# Processing category men_socks_sport
# Processing category men_socks_sneakers
# Processing category men_socks_multipacks
# Processing category men_shoes_slippers
# Processing category men_shoes_flipflops
# Processing category men_shoes_sneakers
# Processing category men_shoes_sandals_espandrillos
# Processing category men_shoes_boots
# Processing category men_shoes_dressed
# Processing category men_shoes_loafers
# Processing category men_nightwearloungewear_pyjamas
# Processing category men_cardigansjumpers_cardigans
# Processing category men_cardigansjumpers_jumpers
# Processing category men_cardigansjumpers_turtleneck
# Processing category men_jacketscoats_vests
# Processing category men_jacketscoats_linen
# Processing category men_jacketscoats_function
# Processing category men_jacketscoats_jackets
# Processing category men_jacketscoats_coats
# Processing category men_jacketscoats_bomberjackets
# Processing category men_jacketscoats_parkas
# Processing category men_jacketscoats_denimjackets
# Processing category men_jacketscoats_bikerjackets
# Processing category men_jacketscoats_windbreakerjackets
# Processing category men_jacketscoats_puffer
# Processing category men_jacketscoats_shirtjackets
# Processing category men_jacketscoats_trenchcoats
# Processing category men_takecare
# Processing category men_knitwear
# 1531
# 1531
